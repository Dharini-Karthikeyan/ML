# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("BRCA.csv")
data.head(5)
# Out:
#      Patient_ID   Age  Gender  Protein1  Protein2  Protein3  Protein4  \
# 0  TCGA-D8-A1XD  36.0  FEMALE  0.080353   0.42638   0.54715  0.273680
# 1  TCGA-EW-A1OX  43.0  FEMALE -0.420320   0.57807   0.61447 -0.031505
# 2  TCGA-A8-A079  69.0  FEMALE  0.213980   1.31140  -0.32747 -0.234260
# 3  TCGA-D8-A1XR  56.0  FEMALE  0.345090  -0.21147  -0.19304  0.124270
# 4  TCGA-BH-A0BF  56.0  FEMALE  0.221550   1.90680   0.52045 -0.311990
#
#   Tumour_Stage                      Histology ER status PR status HER2 status  \
# 0          III  Infiltrating Ductal Carcinoma  Positive  Positive    Negative
# 1           II             Mucinous Carcinoma  Positive  Positive    Negative
# 2          III  Infiltrating Ductal Carcinoma  Positive  Positive    Negative
# 3           II  Infiltrating Ductal Carcinoma  Positive  Positive    Negative
# 4           II  Infiltrating Ductal Carcinoma  Positive  Positive    Negative
#
#                   Surgery_type Date_of_Surgery Date_of_Last_Visit  \
# ...

# %%
np.shape(data)
# Out:
# (341, 16)

# %%
data.dtypes
# Out:
# Patient_ID             object
# Age                   float64
# Gender                 object
# Protein1              float64
# Protein2              float64
# Protein3              float64
# Protein4              float64
# Tumour_Stage           object
# Histology              object
# ER status              object
# PR status              object
# HER2 status            object
# Surgery_type           object
# Date_of_Surgery        object
# Date_of_Last_Visit     object
# Patient_Status         object
# dtype: object

# %%
data.isnull().sum()
# Out:
# Patient_ID             7
# Age                    7
# Gender                 7
# Protein1               7
# Protein2               7
# Protein3               7
# Protein4               7
# Tumour_Stage           7
# Histology              7
# ER status              7
# PR status              7
# HER2 status            7
# Surgery_type           7
# Date_of_Surgery        7
# Date_of_Last_Visit    24
# Patient_Status        20
# dtype: int64

# %%
data.tail(7)
# Out:
#     Patient_ID  Age Gender  Protein1  Protein2  Protein3  Protein4  \
# 334        NaN  NaN    NaN       NaN       NaN       NaN       NaN
# 335        NaN  NaN    NaN       NaN       NaN       NaN       NaN
# 336        NaN  NaN    NaN       NaN       NaN       NaN       NaN
# 337        NaN  NaN    NaN       NaN       NaN       NaN       NaN
# 338        NaN  NaN    NaN       NaN       NaN       NaN       NaN
# 339        NaN  NaN    NaN       NaN       NaN       NaN       NaN
# 340        NaN  NaN    NaN       NaN       NaN       NaN       NaN
#
#     Tumour_Stage Histology ER status PR status HER2 status Surgery_type  \
# 334          NaN       NaN       NaN       NaN         NaN          NaN
# 335          NaN       NaN       NaN       NaN         NaN          NaN
# 336          NaN       NaN       NaN       NaN         NaN          NaN
# 337          NaN       NaN       NaN       NaN         NaN          NaN
# ...

# %%
data=data.dropna(subset=['Patient_ID'])

# %%
np.shape(data)
# Out:
# (334, 16)

# %%
data.isnull().sum()
# Out:
# Patient_ID             0
# Age                    0
# Gender                 0
# Protein1               0
# Protein2               0
# Protein3               0
# Protein4               0
# Tumour_Stage           0
# Histology              0
# ER status              0
# PR status              0
# HER2 status            0
# Surgery_type           0
# Date_of_Surgery        0
# Date_of_Last_Visit    17
# Patient_Status        13
# dtype: int64

# %%
data=data.dropna(subset=['Patient_Status'])

# %%
np.shape(data)
# Out:
# (321, 16)

# %%
data.isnull().sum()
# Out:
# Patient_ID            0
# Age                   0
# Gender                0
# Protein1              0
# Protein2              0
# Protein3              0
# Protein4              0
# Tumour_Stage          0
# Histology             0
# ER status             0
# PR status             0
# HER2 status           0
# Surgery_type          0
# Date_of_Surgery       0
# Date_of_Last_Visit    4
# Patient_Status        0
# dtype: int64

# %%
col=data.columns

# %%
for x in col[1:13]:
    sns.catplot(x=x, y="Patient_Status", data=data)

# %%
g = sns.countplot(data['Patient_Status'])
g.set_xticklabels(['Alive','Dead'])
plt.show()
# Out:
# C:\Users\Brindha\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
data1=data

# %%
np.shape(data1)
# Out:
# (321, 16)

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
data1['Patient_Status'] = le.fit_transform(data1['Patient_Status'])
data1['Gender'] = le.fit_transform(data1['Gender'])
data1['Tumour_Stage'] = le.fit_transform(data1['Tumour_Stage'])
data1['Histology'] = le.fit_transform(data1['Histology'])
data1['ER status'] = le.fit_transform(data1['ER status'])
data1['PR status'] = le.fit_transform(data1['PR status'])
data1['HER2 status'] = le.fit_transform(data1['HER2 status'])
data1['Surgery_type'] = le.fit_transform(data1['Surgery_type'])

# %%
data1['Patient_Status'].value_counts()
# Out:
# 0    255
# 1     66
# Name: Patient_Status, dtype: int64

# %%
"""class_count_0, class_count_1 = data1['Patient_Status'].value_counts()

class_0 = data1[data1['Patient_Status'] == 0]
class_1 = data1[data1['Patient_Status'] == 1]
print('class 0:', class_0.shape)
print('class 1:', class_1.shape)

class_1_over = class_1.sample(class_count_0, replace=True)

test_over = pd.concat([class_1_over, class_0], axis=0)

print("total class of 1 and 0:",test_over['Patient_Status'].value_counts())# plot the count after under-sampeling
test_over['Patient_Status'].value_counts().plot(kind='bar', title='count (target)')"""

# %%
data1.dtypes
# Out:
# Patient_ID             object
# Age                   float64
# Gender                  int32
# Protein1              float64
# Protein2              float64
# Protein3              float64
# Protein4              float64
# Tumour_Stage            int32
# Histology               int32
# ER status               int32
# PR status               int32
# HER2 status             int32
# Surgery_type            int32
# Date_of_Surgery        object
# Date_of_Last_Visit     object
# Patient_Status          int32
# dtype: object

# %%
data1.isnull().sum()
# Out:
# Patient_ID            0
# Age                   0
# Gender                0
# Protein1              0
# Protein2              0
# Protein3              0
# Protein4              0
# Tumour_Stage          0
# Histology             0
# ER status             0
# PR status             0
# HER2 status           0
# Surgery_type          0
# Date_of_Surgery       0
# Date_of_Last_Visit    4
# Patient_Status        0
# dtype: int64

# %%
data1.head(5)
# Out:
#      Patient_ID   Age  Gender  Protein1  Protein2  Protein3  Protein4  \
# 0  TCGA-D8-A1XD  36.0       0  0.080353   0.42638   0.54715  0.273680
# 1  TCGA-EW-A1OX  43.0       0 -0.420320   0.57807   0.61447 -0.031505
# 2  TCGA-A8-A079  69.0       0  0.213980   1.31140  -0.32747 -0.234260
# 3  TCGA-D8-A1XR  56.0       0  0.345090  -0.21147  -0.19304  0.124270
# 4  TCGA-BH-A0BF  56.0       0  0.221550   1.90680   0.52045 -0.311990
#
#    Tumour_Stage  Histology  ER status  PR status  HER2 status  Surgery_type  \
# 0             2          0          0          0            0             1
# 1             1          2          0          0            0             0
# 2             2          0          0          0            0             2
# 3             1          0          0          0            0             1
# 4             1          0          0          0            0             2
#
#   Date_of_Surgery Date_of_Last_Visit  Patient_Status
# ...

# %%
x=data1[['Age','Gender','Protein1','Protein2','Protein3','Protein4','Tumour_Stage','Histology','ER status','PR status','HER2 status','Surgery_type']]
y=data1['Patient_Status']

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3, random_state = 13)

# %%
y_train.value_counts()
# Out:
# 0    169
# 1     55
# Name: Patient_Status, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)

# %%
x_train
# Out:
# array([[-0.01046291, -0.13483997,  0.61742926, ...,  0.        ,
#         -0.33827187,  0.5266697 ],
#        [ 1.39575218, -0.13483997,  0.64795309, ...,  0.        ,
#         -0.33827187,  1.50166155],
#        [ 1.39575218, -0.13483997, -0.35214276, ...,  0.        ,
#         -0.33827187,  0.5266697 ],
#        ...,
#        [-0.01046291, -0.13483997,  0.38839043, ...,  0.        ,
#         -0.33827187, -1.42331399],
#        [ 0.69264464, -0.13483997, -1.48988937, ...,  0.        ,
#         -0.33827187,  0.5266697 ],
#        [-0.55732433, -0.13483997,  2.02570803, ...,  0.        ,
#         -0.33827187,  1.50166155]])

# %% [markdown]
# ## Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()
cla=[]
cla.append(lr)
model1 = lr.fit(x_train,y_train)

# %%
y_pred1 = model1.predict(x_test)

# %%
#test set accuracy
from sklearn.metrics import accuracy_score,confusion_matrix
acc1 = accuracy_score(y_test, y_pred1)
acc1
cm1 = confusion_matrix(y_test, y_pred1)
cm1,acc1
# Out:
# (array([[86,  0],
#         [11,  0]], dtype=int64),
#  0.8865979381443299)

# %%
from sklearn.metrics import plot_confusion_matrix
plot_confusion_matrix(model1, x_test, y_test)

# %%
#from sklearn.metrics import classification_report
#rep1 = classification_report(y_test,y_pred1)
#print(rep1)

# %%
y_train.value_counts()
# Out:
# 0    169
# 1     55
# Name: Patient_Status, dtype: int64

# %%
yt1=model1.predict(x_train)

# %%
#training set accuracy
acc1 = accuracy_score(y_train, yt1)
acc1
cm1 = confusion_matrix(y_train, yt1)
cm1,acc1
# Out:
# (array([[169,   0],
#         [ 55,   0]], dtype=int64),
#  0.7544642857142857)

# %% [markdown]
# ## KNN Classifier

# %%
from sklearn.neighbors import KNeighborsClassifier
kn = KNeighborsClassifier(n_neighbors = 19,metric = "minkowski", p = 2)
cla.append(kn)
model2=kn.fit(x_train, y_train)

# %%
y_pred2 = model2.predict(x_test)

# %%
#test set accuracy
from sklearn.metrics import accuracy_score,confusion_matrix
acc2 = accuracy_score(y_test, y_pred2)
cm2 = confusion_matrix(y_test, y_pred2)
cm2,acc2
# Out:
# (array([[86,  0],
#         [11,  0]], dtype=int64),
#  0.8865979381443299)

# %%
from sklearn.metrics import plot_confusion_matrix
plot_confusion_matrix(model2, x_test, y_test)

# %%
yt2=model2.predict(x_train)

# %%
#training set accuracy
acc2 = accuracy_score(y_train, yt2)
cm2 = confusion_matrix(y_train, yt2)
cm2,acc2
# Out:
# (array([[169,   0],
#         [ 55,   0]], dtype=int64),
#  0.7544642857142857)

# %%
error = []
for i in range(1, 40):
    knn = KNeighborsClassifier(n_neighbors=i)
    knn.fit(x_train, y_train)
    pred_i = knn.predict(x_test)
    error.append(np.mean(pred_i != y_test))

# %%
plt.figure(figsize=(12, 6))
plt.plot(range(1, 40), error, color='green', linestyle='dashed', marker='o',
         markerfacecolor='red', markersize=10)
plt.title('Error Rate K Value')
plt.xlabel('K Value')
plt.ylabel('Mean Error')
# Out:
# Text(0, 0.5, 'Mean Error')

# %%
acc = []
from sklearn import metrics
for i in range(1,40):
    neigh = KNeighborsClassifier(n_neighbors = i).fit(x_train,y_train)
    yhat = neigh.predict(x_test)
    acc.append(metrics.accuracy_score(y_test, yhat))
    
plt.figure(figsize=(10,6))
plt.plot(range(1,40),acc,color = 'blue',linestyle='dashed',marker='o',markerfacecolor='red', markersize=10)
plt.title('accuracy vs. K Value')
plt.xlabel('K')
plt.ylabel('Accuracy')
# Out:
# Text(0, 0.5, 'Accuracy')

# %% [markdown]
# ## Naive Bayes

# %%
from sklearn import preprocessing
min_max_scaler = preprocessing.MinMaxScaler()
X_train = pd.DataFrame(data=min_max_scaler.fit_transform(x_train), columns=['Age','Gender','Protein1','Protein2','Protein3','Protein4','Tumour_Stage','Histology','ER status','PR status','HER2 status','Surgery_type'])
X_test =pd.DataFrame(data=min_max_scaler.fit_transform(x_test), columns=['Age','Gender','Protein1','Protein2','Protein3','Protein4','Tumour_Stage','Histology','ER status','PR status','HER2 status','Surgery_type'])

# %%
#---------------gaussian nb-----------------
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
cla.append(gnb)
gnb=gnb.fit(X_train, y_train)

# %%
y_pred3a  =  gnb.predict(X_test)

# %%
#test set accuracy
from sklearn.metrics import accuracy_score,confusion_matrix
acc3 = accuracy_score(y_test, y_pred3a)
cm3 = confusion_matrix(y_test, y_pred3a)
cm3,acc3
# Out:
# (array([[86,  0],
#         [11,  0]], dtype=int64),
#  0.8865979381443299)

# %%
yt3a=model3a.predict(X_train)

# %%
#training set accuracy
acc3 = accuracy_score(y_train, yt3a)
cm3 = confusion_matrix(y_train, yt3a)
cm3,acc3
# Out:
# (array([[169,   0],
#         [ 55,   0]], dtype=int64),
#  0.7544642857142857)

# %%
#---------------------multinomial nb-----------------
from sklearn.naive_bayes import MultinomialNB
mnb = MultinomialNB()
cla.append(mnb)
model3b = mnb.fit(X_train, y_train)

# %%
y_pred3b  =  model3b.predict(X_test)

# %%
#test set accuracy
from sklearn.metrics import accuracy_score,confusion_matrix
acc3b = accuracy_score(y_test, y_pred3b)
cm3b = confusion_matrix(y_test, y_pred3b)
cm3b,acc3b
# Out:
# (array([[86,  0],
#         [11,  0]], dtype=int64),
#  0.8865979381443299)

# %%
yt3b=model3b.predict(X_train)

# %%
#training set accuracy
acc3b = accuracy_score(y_train, yt3b)
cm3b = confusion_matrix(y_train, yt3b)
cm3b,acc3b
# Out:
# (array([[169,   0],
#         [ 55,   0]], dtype=int64),
#  0.7544642857142857)

# %%
#---------------------Bernouli nb-----------------
from sklearn.naive_bayes import BernoulliNB
bnb = BernoulliNB()
cla.append(bnb)
model3c = bnb.fit(X_train, y_train)

# %%
y_pred3c  =  model3c.predict(X_test)

# %%
#test set accuracy
from sklearn.metrics import accuracy_score,confusion_matrix
acc3 = accuracy_score(y_test, y_pred3c)
cm3 = confusion_matrix(y_test, y_pred3c)
cm3,acc3
# Out:
# (array([[85,  1],
#         [11,  0]], dtype=int64),
#  0.8762886597938144)

# %%
yt3c=model3c.predict(X_train)

# %%
#training set accuracy
acc3 = accuracy_score(y_train, yt3c)
cm3 = confusion_matrix(y_train, yt3c)
cm3,acc3
# Out:
# (array([[169,   0],
#         [ 54,   1]], dtype=int64),
#  0.7589285714285714)

# %% [markdown]
# ## Decision tree

# %%
from sklearn.tree import DecisionTreeClassifier
clf=DecisionTreeClassifier(criterion="entropy", max_depth=3)
cla.append(clf)
clf1=clf.fit(x_train,y_train)

# %%
y_pred4=clf1.predict(x_test)

# %%
#test set accuracy
from sklearn.metrics import accuracy_score,confusion_matrix
acc4 = accuracy_score(y_test, y_pred4)
cm4 = confusion_matrix(y_test, y_pred4)
cm4,acc4
# Out:
# (array([[83,  3],
#         [10,  1]], dtype=int64),
#  0.865979381443299)

# %%
yt4=clf1.predict(x_train)

# %%
#training set accuracy
acc4 = accuracy_score(y_train, yt4)
cm34 = confusion_matrix(y_train, yt4)
cm4,acc4
# Out:
# (array([[83,  3],
#         [10,  1]], dtype=int64),
#  0.7857142857142857)

# %%
from sklearn import tree
import matplotlib.pyplot as plt
text_represent = tree.export_text(clf)
print(text_represent)
fig = plt.figure(figsize = (25,25))
tree.plot_tree(clf,filled = True)
# Out:
# |--- feature_3 <= -0.51
# |   |--- feature_2 <= -0.08
# |   |   |--- feature_5 <= -1.68
# |   |   |   |--- class: 0
# |   |   |--- feature_5 >  -1.68
# |   |   |   |--- class: 0
# |   |--- feature_2 >  -0.08
# |   |   |--- feature_5 <= 1.81
# |   |   |   |--- class: 0
# |   |   |--- feature_5 >  1.81
# |   |   |   |--- class: 1
# |--- feature_3 >  -0.51
# |   |--- feature_4 <= 0.82
# |   |   |--- feature_11 <= -0.94
# |   |   |   |--- class: 0
# |   |   |--- feature_11 >  -0.94
# |   |   |   |--- class: 0
# |   |--- feature_4 >  0.82
# |   |   |--- feature_4 <= 1.05
# |   |   |   |--- class: 1
# |   |   |--- feature_4 >  1.05
# |   |   |   |--- class: 0
# [Text(697.5, 1189.125, 'X[3] <= -0.512\nentropy = 0.804\nsamples = 224\nvalue = [169, 55]'),
#  Text(348.75, 849.375, 'X[2] <= -0.084\nentropy = 0.633\nsamples = 69\nvalue = [58, 11]'),
#  Text(174.375, 509.625, 'X[5] <= -1.681\nentropy = 0.801\nsamples = 41\nvalue = [31, 10]'),
# ...

# %% [markdown]
# ## Random forest classifier

# %%
from sklearn.ensemble import RandomForestClassifier
cls = RandomForestClassifier(n_estimators = 100) 
cla.append(cls)
cls=cls.fit(x_train, y_train)

# %%
y_pred = cls.predict(x_test)

# %%
#test set accuracy
from sklearn.metrics import accuracy_score,confusion_matrix
acc = accuracy_score(y_test, y_pred)
cm = confusion_matrix(y_test, y_pred)
cm,acc
# Out:
# (array([[86,  0],
#         [11,  0]], dtype=int64),
#  0.8865979381443299)

# %%
yt=cls.predict(x_train)

# %%
#training set accuracy
acc = accuracy_score(y_train, yt)
cm = confusion_matrix(y_train, yt)
cm,acc
# Out:
# (array([[169,   0],
#         [  0,  55]], dtype=int64),
#  1.0)

# %%
#for cl in cla:
 #   cl.fit(X_train, y_train)
  #  y_pred= cl.predict(X_test)
#    acc = accuracy_score(y_test, y_pred)
 #   print("Accuracy of %s is %s"%(cl, acc))
  #  cm = confusion_matrix(y_test, y_pred)
#    print("Confusion Matrix of %s is %s"%(cl, cm))
# Out:
# Accuracy of LogisticRegression() is 0.8865979381443299
# Confusion Matrix of LogisticRegression() is [[86  0]
#  [11  0]]
# Accuracy of KNeighborsClassifier(n_neighbors=15) is 0.8762886597938144
# Confusion Matrix of KNeighborsClassifier(n_neighbors=15) is [[85  1]
#  [11  0]]
# Accuracy of KNeighborsClassifier(n_neighbors=19) is 0.8865979381443299
# Confusion Matrix of KNeighborsClassifier(n_neighbors=19) is [[86  0]
#  [11  0]]
# Accuracy of GaussianNB() is 0.8865979381443299
# Confusion Matrix of GaussianNB() is [[86  0]
#  [11  0]]
# Accuracy of MultinomialNB() is 0.8865979381443299
# Confusion Matrix of MultinomialNB() is [[86  0]
#  [11  0]]
# Accuracy of BernoulliNB() is 0.8762886597938144
# Confusion Matrix of BernoulliNB() is [[85  1]
#  [11  0]]
# Accuracy of DecisionTreeClassifier(criterion='entropy', max_depth=3) is 0.8762886597938144
# Confusion Matrix of DecisionTreeClassifier(criterion='entropy', max_depth=3) is [[85  1]
#  [11  0]]
# ...
